# %%
import numpy as np
import cv2
import cv2
import matplotlib.pyplot as plt

from utils import *
from darknet import Darknet

# %%
# Set the location and name of the cfg file
cfg_file = './cfg/yolov3.cfg'

# Set the location and name of the pre-trained weights file
weight_file = './weights/yolov3.weights'

# Set the location and name of the COCO object classes file
namesfile = 'data/coco.names'

# Load the network architecture
m = Darknet(cfg_file)

# Load the pre-trained weights
m.load_weights(weight_file)

# Load the COCO object classes
class_names = load_class_names(namesfile)
# Out:
# Loading weights. Please Wait...100.00% Complete

# %%
cv2.namedWindow("frame")

vc = cv2.VideoCapture(0)


while (True):
    
    if vc.isOpened():
        rval, frame = vc.read()
    else:
        rval = False
    
    original_image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    # We resize the image to the input width and height of the first layer of the network.    
    resized_image = cv2.resize(original_image, (m.width, m.height))

    
    
    # Set the IOU threshold. Default value is 0.4
    iou_thresh = 0.4

    # Set the NMS threshold. Default value is 0.6
    nms_thresh = 0.6

    # Detect objects in the image
    boxes = detect_objects(m, resized_image, iou_thresh, nms_thresh)
    
    #print_objects(boxes, class_names)
    
    plot_boxes(original_image, boxes, class_names, plot_labels = True)
    
    
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
vc.release()
cv2.destroyAllWindows()
# Out:
# It took 0.356 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
# It took 0.392 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
# It took 0.383 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
# It took 0.379 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
# It took 0.412 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
# It took 0.374 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
# It took 0.382 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
# It took 0.441 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
# It took 0.401 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
# It took 0.386 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
# It took 0.461 seconds to detect the objects in the image.
#
# Number of Objects Detected: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-9e5a58b3ad7e> in <module>
#      24
#      25     # Detect objects in the image
# ---> 26     boxes = detect_objects(m, resized_image, iou_thresh, nms_thresh)
#      27
#      28     #print_objects(boxes, class_names)
#
# ~/git/Pytorch Implementations Alex VGG Resnet/Pytorch_Object_Detection/utils.py in detect_objects(model, img, iou_thresh, nms_thresh)
#     117     # probability of detection. All predicted bounding boxes with a value less than
#     118     # the given NMS threshold will be removed.
# --> 119     list_boxes = model(img, nms_thresh)
#     120
#     121     # Make a new list with all the bounding boxes returned by the neural network
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/git/Pytorch Implementations Alex VGG Resnet/Pytorch_Object_Detection/darknet.py in forward(self, x, nms_thresh)
#      83                 continue
#      84             elif block['type'] in ['convolutional', 'upsample']:
# ---> 85                 x = self.models[ind](x)
#      86                 outputs[ind] = x
#      87             elif block['type'] == 'route':
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# KeyboardInterrupt:

# %%
vc.release()
cv2.destroyAllWindows()
